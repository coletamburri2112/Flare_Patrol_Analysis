# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
import

# %%
file = '/Users/coletamburri/Desktop/2024Oct3_IRISflare_kmeans/RSM20241003T121820_0013_HA.fits'

# %%
halpha = fits.open(file)

# %%
halpha
# Out:
# [<astropy.io.fits.hdu.image.PrimaryHDU object at 0x16db91e20>, <astropy.io.fits.hdu.compressed.compressed.CompImageHDU object at 0x16dc40380>]

# %%
np.shape(halpha[1].data)
# Out:
# (118, 2313, 2304)

# %%
halpha[1].header
# Out:
# XTENSION= 'IMAGE   '           / binary table extension
# BITPIX  =                   16 / data type of original image
# NAXIS   =                    3 / Number of data axes
# NAXIS1  =                 2304 / Length of data axis 1 (slit dimension)
# NAXIS2  =                 2313 / Length of data axis 2 (scanning steps)
# NAXIS3  =                  118 / Length of data axis 3 (wavelength dimension)
# PCOUNT  =                    0 / number of group parameters
# GCOUNT  =                    1 / number of groups
# TELESCOP= 'CHASE-HIS'          / Telescop Name
# BIN     =                    2 / Binning mode
# DATE_OBS= '2024-10-03T12:18:20' / Observation time
# CRPIX1  =    1171.673739740899 / X coordinate of solar center in pixel
# CUNIT1  = 'arcsec  '           / unit of x-axis
# CDELT1  =                 1.04 / Pixel spatial resolution along x-axis
# CRVAL1  =                  0.0 / E-W arcsec of solar center
# CRPIX2  =    1160.247660069555 / Y coordinate of solar center in pixel
# CUNIT2  = 'arcsec  '           / unit of y-axis
# CDELT2  =                 1.04 / Pixel spatial resolution along y-axis
# CRVAL2  =                  0.0 / N-S arcsec of solar center
# CRPIX3  =                  0.0 / Reference pixel at the wavelength dimension
# CUNIT3  = 'angstrom'           / unit of z-axis
# CDELT3  =  0.04852978625928615 / Angstrom per pixel
# CRVAL3  =    6559.436088269187 / Wavelength at the reference pixel
# STEPTIME=                 0.01 / One-step scanning duration,unit(s)
# PRODATE = '2024-10-03T23:09:23' / File creation date
# STR_TIME= '2024-10-03T12:18:20' / scanning start time
# END_TIME= '2024-10-03T12:19:06' / scanning end time
# EXP_TIME=                0.005 / Exposure time for raster scanning,unit(s)
# ORID    = '16465-1 '           / station ID
# FRM_NUM = '1~2313  '           / Frame number of a scanning series
# SPECLINE= 'HA      '           / Spectral line
# WAVE_LEN=              6562.82 / Wavelength of Ha line core
# SAT_POS1=      -1208.978515625 / Satellite x-position in J2000 coordinate system
# SAT_POS2=    1267.086547851562 / Satellite y-position in J2000 coordinate system
# SAT_POS3=      -6670.271484375 / Satellite z-position in J2000 coordinate system
# SAT_VEL1=   -1.471135973930359 / Satellite x-velocity in J2000 coordinate system
# SAT_VEL2=    7.262734413146973 / Satellite y-velocity in J2000 coordinate system
# SAT_VEL3=    1.647984504699707 / Satellite z-velocity in J2000 coordinate system
# INST_ROT=                    0 / Angle of Solar North wrt CMOS y-axis.
# R_SUN   =    919.7000122070312 / Radius of the Sun in pixels on the CCD
# RSUN_OBS=    959.7989327392579 / Apparent solar radius seen by CHASE
# B0      =    6.585584158955157 / latitude of point at disk center.
# OBS_MOD = 'RSM     '           / Raster scanning mode
# LVL_NUM =                    1 / Data processing level
# RSUN_REF=    919.4880672670112
# COMMENT Spectral curvature corrected
# COMMENT Dark subtracted
# COMMENT Flat-field corrected
# COMMENT Processed by RSM_prep

# %%
wavelengths = np.arange(halpha[1].header['CRVAL3'],halpha[1].header['CRVAL3']+halpha[1].header['CDELT3']*118,halpha[1].header['CDELT3'])

# %%
meanhalpha = np.mean(halpha[1].data,0)

# %%
plt.pcolormesh(meanhalpha)
plt.axhline(870)
plt.axhline(710)
plt.axvline(1150)
plt.axvline(1330)
plt.xlim([1150,1330])
plt.ylim([710,870])
plt.axhline(808)
plt.axvline(1240)

# %%
flaresampspec = halpha[1].data[:,808,1240]

# %%
positions = np.linspace(780,8,51)
positions
# Out:
# array([780., 781., 782., 783., 784., 785., 786., 787., 788., 789., 790.,
#        791., 792., 793., 794., 795., 796., 797., 798., 799., 800., 801.,
#        802., 803., 804., 805., 806., 807., 808., 809., 810., 811., 812.,
#        813., 814., 815., 816., 817., 818., 819., 820., 821., 822., 823.,
#        824., 825., 826., 827., 828., 829., 830.])

# %%
fig,ax=plt.subplots(figsize=(10,5))
n_steps = 29
colors = plt.cm.turbo(np.linspace(0,1,n_steps))
for i in np.linspace(780,808,n_steps):
    flaresampspec = halpha[1].data[:,int(i),1240]
    ax.plot(wavelengths,flaresampspec,label=str(i),color=colors[int(i-780)])
    #ax.legend()
ax.axvline(halpha[1].header['WAVE_LEN'])
ax.set_title('lower ribbon')
# Out:
# Text(0.5, 1.0, 'lower ribbon')

# %%
fig,ax=plt.subplots(figsize=(10,5))
n_steps = 33
colors = plt.cm.turbo(np.linspace(0,1,n_steps))
for i in np.linspace(808,840,n_steps):
    flaresampspec = halpha[1].data[:,int(i),1240]
    ax.plot(wavelengths,flaresampspec,label=str(i),color=colors[int(i-808)])
    #ax.legend()
ax.axvline(halpha[1].header['WAVE_LEN'])
ax.set_title('upper ribbon')
# Out:
# Text(0.5, 1.0, 'upper ribbon')

# %%
halph_data = halpha[1].data

# %%
wl_cent = halpha[1].header['CRVAL3']
wl_grids = halpha[1].header['CDELT3']
nwl = 118

wl_range = np.linspace(wl_cent,wl_cent+(nwl*wl_grids),nwl)

# %%
wl_m[56]
# Out:
# 6559.313726842294

# %%
wl_cent
# Out:
# 6559.436088269187

# %%
plt.plot(wl_range,halph_data[:,808,1250])
