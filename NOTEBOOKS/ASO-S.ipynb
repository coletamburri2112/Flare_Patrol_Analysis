# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits

# %%
filename1 = '/Users/coletamburri/Downloads/wst_lev12_20240811_223122.632_v01.fits'
filename2 = '/Users/coletamburri/Downloads/wst_lev12_20240811_223322.633_v01.fits'
filename3 = '/Users/coletamburri/Downloads/wst_lev12_20240811_223522.634_v01.fits'

# %%
file22_31 = fits.open(filename1)
file22_33 = fits.open(filename2)
file22_35 = fits.open(filename3)

# %%
fig,ax=plt.subplots(dpi=200)
ax.pcolormesh(file22_31[0].data,cmap='grey')
ax.set_xlim([3850,3950])
ax.set_ylim([1780,1900])
ax.set_aspect('equal')

# %%
fig,ax=plt.subplots(dpi=200)
ax.pcolormesh(file22_33[0].data,cmap='grey')
ax.set_xlim([3850,3950])
ax.set_ylim([1780,1900])
ax.set_aspect('equal')

# %%
fig,ax=plt.subplots(dpi=200)
ax.pcolormesh(file22_35[0].data,cmap='grey')
ax.set_xlim([3850,3950])
ax.set_ylim([1780,1900])
ax.set_aspect('equal')
