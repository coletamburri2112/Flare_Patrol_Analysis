# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
import os

# %%
directory_name = '/Volumes/ViSP_External/pid_3_37/'
subdir1 = 'NFMGBO' # 2 June 2025 20:34 UT - active region
subdir2 = 'UDXTYO' # 2 June 2024 22:53 UT - disk center

# %%
filelist = os.listdir(directory_name+subdir2)

# %%
filelist.sort()
del filelist[:3]

# %%
filelist
# Out:
# ['VISP_2025_06_02T22_53_59_157188_00589600_I_UDXTYO_L1.fits',
#  'VISP_2025_06_02T22_53_59_207349_00589600_I_UDXTYO_L1.fits',
#  'VISP_2025_06_02T22_53_59_257510_00589600_I_UDXTYO_L1.fits',
#  'VISP_2025_06_02T22_53_59_307671_00589600_I_UDXTYO_L1.fits',
#  'VISP_2025_06_02T22_53_59_357832_00589600_I_UDXTYO_L1.fits',
#  'VISP_2025_06_02T22_53_59_407993_00589600_I_UDXTYO_L1.fits',
#  'VISP_2025_06_02T22_53_59_458154_00589600_I_UDXTYO_L1.fits',
#  'VISP_2025_06_02T22_53_59_508315_00589600_I_UDXTYO_L1.fits',
#  'VISP_2025_06_02T22_53_59_558475_00589600_I_UDXTYO_L1.fits',
#  'VISP_2025_06_02T22_53_59_608636_00589600_I_UDXTYO_L1.fits',
#  'VISP_2025_06_02T22_53_59_658797_00589600_I_UDXTYO_L1.fits',
#  'VISP_2025_06_02T22_53_59_708958_00589600_I_UDXTYO_L1.fits',
#  'VISP_2025_06_02T22_53_59_759119_00589600_I_UDXTYO_L1.fits',
#  'VISP_2025_06_02T22_53_59_809280_00589600_I_UDXTYO_L1.fits',
#  'VISP_2025_06_02T22_53_59_859441_00589600_I_UDXTYO_L1.fits',
# ...

# %%
file1 = fits.open(directory_name+subdir2+'/'+filelist[0])

# %%
file1[1].header
# Out:
# XTENSION= 'IMAGE   '           / Image extension
# BITPIX  =                  -32 / array data type
# NAXIS   =                    3 / number of array dimensions
# NAXIS1  =                 2550
# NAXIS2  =                  930
# NAXIS3  =                    1
# PCOUNT  =                    0 / number of parameters
# GCOUNT  =                    1 / number of groups
# EXTNAME = 'observation'        / name of this binary table extension
# BUNIT   = '' / Values are relative to disk center. See calibration docs.
# DATE    = '2026-03-06T16:36:50.981' / UTC Date/Time of HDU creation
# DATE-BEG= '2025-06-02T22:53:59.157188' / Exposure start time
# DATE-END= '2025-06-02T22:53:59.197' / Exposure end time
# TELAPSE =  0.03981194458901882 / [s] Time elapsed during exposure
# DATE-AVG= '2025-06-02T22:53:59.177094' / Temporal midpoint of exposure
# ORIGIN  = 'National Solar Observatory' / Origin
# TELESCOP= 'Daniel K. Inouye Solar Telescope' / Telescope
# ...

# %%
file1[1].header['ATMOS_R0']
# Out:
# 0.0449103281837898

# %%
r0 = []
times = []
for i in range(len(filelist)):
    file1 = fits.open(directory_name+subdir2+'/'+filelist[i])
    if 'ATMOS_R0' in file1[1].header:
        r0.append(file1[1].header['ATMOS_R0'])
        times.append(file1[1].header['DATE-BEG'])
    else:
        r0.append(0)
        times.append(0)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[54], line 4
#       2 times = []
#       3 for i in range(len(filelist)):
# ----> 4     file1 = fits.open(directory_name+subdir2+'/'+filelist[i])
#       5     if 'ATMOS_R0' in file1[1].header:
#       6         r0.append(file1[1].header['ATMOS_R0'])
#
# File /opt/anaconda3/lib/python3.13/site-packages/astropy/io/fits/hdu/hdulist.py:224, in fitsopen(name, mode, memmap, save_backup, cache, lazy_load_hdus, ignore_missing_simple, use_fsspec, fsspec_kwargs, decompress_in_memory, **kwargs)
#     221 if not name:
#     222     raise ValueError(f"Empty filename: {name!r}")
# --> 224 return HDUList.fromfile(
#     225     name,
#     226     mode,
#     227     memmap,
#     228     save_backup,
#     229     cache,
#     230     lazy_load_hdus,
#     231     ignore_missing_simple,
#     232     use_fsspec=use_fsspec,
# ...

# %%
for i in range(len(r0)):
    if r0[i]=='':
        r0[i]=0

# %%
plt.plot(r0)

# %%
r0[1351]
# Out:
# 0.0862614651730373

# %%
filelist[1350:1361]
# Out:
# ['VISP_2025_06_02T22_57_56_705022_00589600_I_UDXTYO_L1.fits',
#  'VISP_2025_06_02T22_57_56_755183_00589600_I_UDXTYO_L1.fits',
#  'VISP_2025_06_02T22_57_56_805344_00589600_I_UDXTYO_L1.fits',
#  'VISP_2025_06_02T22_57_56_855504_00589600_I_UDXTYO_L1.fits',
#  'VISP_2025_06_02T22_57_56_905665_00589600_I_UDXTYO_L1.fits',
#  'VISP_2025_06_02T22_57_56_955826_00589600_I_UDXTYO_L1.fits',
#  'VISP_2025_06_02T22_57_57_005987_00589600_I_UDXTYO_L1.fits',
#  'VISP_2025_06_02T22_57_57_056148_00589600_I_UDXTYO_L1.fits',
#  'VISP_2025_06_02T22_57_57_106309_00589600_I_UDXTYO_L1.fits',
#  'VISP_2025_06_02T22_57_57_156470_00589600_I_UDXTYO_L1.fits',
#  'VISP_2025_06_02T22_57_57_206631_00589600_I_UDXTYO_L1.fits']

# %%
import shutil
destination_directory = '/Users/coletamburri/Desktop/NaI_4Kevin/'
for i in range(1350,1361,1):
    sourcefile = directory_name+subdir2+'/'+filelist[i]
    print(sourcefile)
    shutil.copy(sourcefile,destination_directory)
# Out:
# /Volumes/ViSP_External/pid_3_37/UDXTYO/VISP_2025_06_02T22_57_56_705022_00589600_I_UDXTYO_L1.fits
# /Volumes/ViSP_External/pid_3_37/UDXTYO/VISP_2025_06_02T22_57_56_755183_00589600_I_UDXTYO_L1.fits
# /Volumes/ViSP_External/pid_3_37/UDXTYO/VISP_2025_06_02T22_57_56_805344_00589600_I_UDXTYO_L1.fits
# /Volumes/ViSP_External/pid_3_37/UDXTYO/VISP_2025_06_02T22_57_56_855504_00589600_I_UDXTYO_L1.fits
# /Volumes/ViSP_External/pid_3_37/UDXTYO/VISP_2025_06_02T22_57_56_905665_00589600_I_UDXTYO_L1.fits
# /Volumes/ViSP_External/pid_3_37/UDXTYO/VISP_2025_06_02T22_57_56_955826_00589600_I_UDXTYO_L1.fits
# /Volumes/ViSP_External/pid_3_37/UDXTYO/VISP_2025_06_02T22_57_57_005987_00589600_I_UDXTYO_L1.fits
# /Volumes/ViSP_External/pid_3_37/UDXTYO/VISP_2025_06_02T22_57_57_056148_00589600_I_UDXTYO_L1.fits
# /Volumes/ViSP_External/pid_3_37/UDXTYO/VISP_2025_06_02T22_57_57_106309_00589600_I_UDXTYO_L1.fits
# /Volumes/ViSP_External/pid_3_37/UDXTYO/VISP_2025_06_02T22_57_57_156470_00589600_I_UDXTYO_L1.fits
# ...
